# %% [markdown]
# Only for testing purposes to visualise Results, not part of final product

# %%
# %run ../atf/atf.ipynb

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15, 8))
plt.scatter(portfolios_stats.loc[:, "Risk"], portfolios_stats.loc[:, "Return"], s= 20, c = portfolios_stats.loc[:, "Sharpe"], cmap = "coolwarm", vmin = 0.76, vmax = 1.18, alpha = 0.8)
plt.colorbar()
plt.scatter(stats.loc["MSRP", "Risk"], stats.loc["MSRP", "Return"],s= 300, c = "black", marker = "*")
plt.xlabel("annualized Risk", fontsize = 15)
plt.ylabel("annualized Return", fontsize = 15)
plt.title("Max Sharpe Ratio Portfolio", fontsize = 20)
plt.show()
